# %%
# %matplotlib inline
# Out:
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 27 days

# %%
from bayes_detect.test import test_image

# %%
SrcArray = [[43.71, 22.91, 10.54, 3.34],
            [101.62, 40.60, 1.37, 3.40],
            [92.63, 110.56, 1.81, 3.66],
            [183.60, 85.90, 1.23, 5.06],
            [34.12, 162.54, 1.95, 6.02],
            [153.87, 169.18, 1.06, 6.61],
            [155.54, 32.14, 1.46, 4.05],
            [130.56, 183.48, 1.63, 4.11]]
height = 200
width = 200
#format is [X,Y,A,R] for each source

data_map = test_image.make_source(src_array = SrcArray,height=height, width=width)

# %%
noise = 2.0
data_map = test_image.add_gaussian_noise(mean=0,sd=noise,data=data_map)

# %%
prior_array = [[0.0,200.0],[0.0,200.0],[1.0,12.5],[2.0,9.0]]
#uniform prior for each parameter. Sets them up in order of [X,Y,A,R]

# %% [markdown]
# Parameters
#
#     *iterations
#         *number of iterations of the sampler
#         *setting a non positive number will default the system to run until convergence
#
#     *sample_params
#         *a dictionary with keys and values corresponding to parameters of the sampler
#         *{"type":"uniform"}
#             -uniform sampler. This is unusably slow.
#         *{"type":"metropolis", "disp":dispersion_value}
#             -metropolis hastings. Dispersion value can be set to anything. Default was 8.0
#         *{"type":"clustered_ellipsoidal", "minPts":min_pts_value, "eps":eps_value}
#             -runs clustering every iteration
#             -samples within a ellipsoid that encloses the cluster
#             -minPts and eps usually are 10
#         *{"type":"new", "minPts":min_pts_value, "eps":eps_value}
#             -same as above, except it only clusters every 30 iterations
#
#     *stop_by_evidence
#         -True = run until convergence. This is automatically set if iterations is nonsensical.
#         -False = run for specified iterations

# %%
from bayes_detect.source_detection import detector
detector.run_source_detect(data_map = data_map, height = height, width = width, active_samples = 1200, iterations = -1,
                           sample_params = {"type":"new", "minPts":10, "eps":10}, prior = prior_array, noise_rms = noise)
# Out:
# Iteration: 1  maxZ: 5202.12228481
# Iteration: 1000  maxZ: 685.949473705
# Iteration: 2000  maxZ: 473.271277658
# Iteration: 3000  maxZ: 422.667707631
# Iteration: 4000  maxZ: 405.313460613
# Iteration: 5000  maxZ: 432.669870637
# Iteration: 6000  maxZ: 428.523350011
# Iteration: 7000  maxZ: 425.188163453
# Iteration: 8000  maxZ: 444.933555987
# Iteration: 9000  maxZ: 435.338616232
# Iteration: 10000  maxZ: 425.099620752
# Iteration: 11000  maxZ: 379.368294
# Iteration: 12000  maxZ: 289.73858148
# Iteration: 13000  maxZ: 214.463946574
# Iteration: 14000  maxZ: 153.607288012
# Iteration: 15000  maxZ: 109.889204097
# Iteration: 16000  maxZ: 71.719826407
# Iteration: 17000  maxZ: 46.4428103183
# Iteration: 18000  maxZ: 30.0507357158
# Iteration: 19000  maxZ: 17.3407293492
# Iteration: 20000  maxZ: 8.90547367609
# Iteration: 21000  maxZ: 3.43133469888
# elapsed time: 0:18:38.533935
# log evidence: -112325.454232
# number of iterations: -1
# likelihood calculations: 970092
